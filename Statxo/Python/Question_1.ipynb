# %%
# Task - Question 1
# Write a code to import Dataframe in Python

# %%
import pandas as pd

# %%
# Way 1
data = pd.DataFrame({
    'Emp ID': [10001, 10002, 10003, 10001, 10002, 10003, 10005, 10007, 10004, 10005, 10006, 10007, 10008],
    'Region': ['East', 'East', 'East', 'East', 'East', 'East', 
               'West', 'West', 'East', 'West', 'West', 'West', 'West'],
    'Name': ['DeRusha, Joe', 'De Pasquale, Richard', 'Dobbert, Susan', 'DeRusha, Joe', 'De Pasquale, Richard', 
             'Dobbert, Susan', 'Dunton, Donna', 'De Sousa, Kristi', 'Dillard, Susan', 
             'Dunton, Donna', 'De Vries, John', 'De Sousa, Kristi', 'Defonso, Daniel'],
    'Supplier Name': ['Dell', 'Dell Inc', 'Dell Ltd', 'ABBGroup', 'Google India', 'DHL', 'Google USA', 
                      'DHL Ltd', 'ABB', 'Office Supplies', 'Dell USA', 'Ericson', 'Ericson USA'],
    'Harmonized Supplier Name': [None] * 13,
    'Department': ['5255-Data/Connectivity Sales', '5256-Sales Mgt & Support', '5257-Auto Sales', '5255-Data/Connectivity Sales', 
                   '5256-Sales Mgt & Support', '5257-Auto Sales', '5259-Sales Channel', '5263-Sales Support', '5258-IAP Sales', 
                   '5259-Sales Channel', '5262-Auto GM', '5263-Sales Support', '5264-ARD Sales'],
    'Month': ['Jan'] * 13,
    'Year': ['FY13'] * 13,
    'Sales': [100000, 150000, 200000, 100000, 150000, 200000, 300000, 400000, 250000, 300000, 350000, 400000, 450000],
    'Discounts': [25000, 30000, 35000, 25000, 30000, 35000, 45000, 55000, 40000, 45000, 50000, 55000, 60000],
    'Date': ['24-01-2023', '1/1/2023', '1/8/2023', '1/28/2023', '1/21/2023', '1/23/2023', '1/14/2023', '28-01-2023', 
             '1/28/2023', '1/21/2023', '1/23/2023', '1/14/2023', '28-01-2023']
             })

# %%
data
# Out:
#     Emp ID Region                  Name    Supplier Name  \
# 0    10001   East          DeRusha, Joe             Dell
# 1    10002   East  De Pasquale, Richard         Dell Inc
# 2    10003   East        Dobbert, Susan         Dell Ltd
# 3    10001   East          DeRusha, Joe         ABBGroup
# 4    10002   East  De Pasquale, Richard     Google India
# 5    10003   East        Dobbert, Susan              DHL
# 6    10005   West         Dunton, Donna       Google USA
# 7    10007   West      De Sousa, Kristi          DHL Ltd
# 8    10004   East        Dillard, Susan              ABB
# 9    10005   West         Dunton, Donna  Office Supplies
# 10   10006   West        De Vries, John         Dell USA
# 11   10007   West      De Sousa, Kristi          Ericson
# 12   10008   West       Defonso, Daniel      Ericson USA
#
#    Harmonized Supplier Name                    Department Month  Year   Sales  \
# 0                      None  5255-Data/Connectivity Sales   Jan  FY13  100000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Emp ID                    13 non-null     int64
#  1   Region                    13 non-null     object
#  2   Name                      13 non-null     object
#  3   Supplier Name             13 non-null     object
#  4   Harmonized Supplier Name  0 non-null      object
#  5   Department                13 non-null     object
#  6   Month                     13 non-null     object
#  7   Year                      13 non-null     object
#  8   Sales                     13 non-null     int64
#  9   Discounts                 13 non-null     int64
#  10  Date                      13 non-null     object
# dtypes: int64(3), object(8)
# memory usage: 1.2+ KB

# %%
# Way 2
data_csv = pd.read_csv('data.csv')

# %%
data_csv
# Out:
#     Emp ID Region                  Name    Supplier Name  \
# 0    10001   East          DeRusha, Joe             Dell
# 1    10002   East  De Pasquale, Richard         Dell Inc
# 2    10003   East        Dobbert, Susan         Dell Ltd
# 3    10001   East          DeRusha, Joe         ABBGroup
# 4    10002   East  De Pasquale, Richard     Google India
# 5    10003   East        Dobbert, Susan              DHL
# 6    10005   West         Dunton, Donna       Google USA
# 7    10007   West      De Sousa, Kristi          DHL Ltd
# 8    10004   East        Dillard, Susan              ABB
# 9    10005   West         Dunton, Donna  Office Supplies
# 10   10006   West        De Vries, John         Dell USA
# 11   10007   West      De Sousa, Kristi          Ericson
# 12   10008   West       Defonso, Daniel      Ericson USA
#
#     Harmonized Supplier Name                    Department Month  Year  \
# 0                        NaN  5255-Data/Connectivity Sales   Jan  FY13
# ...

# %%
data_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Emp ID                    13 non-null     int64
#  1   Region                    13 non-null     object
#  2   Name                      13 non-null     object
#  3   Supplier Name             13 non-null     object
#  4   Harmonized Supplier Name  0 non-null      float64
#  5   Department                13 non-null     object
#  6   Month                     13 non-null     object
#  7   Year                      13 non-null     object
#  8   Sales                     13 non-null     int64
#  9   Discounts                 13 non-null     int64
#  10  Date                      13 non-null     object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.2+ KB
